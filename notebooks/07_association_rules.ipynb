# %% [markdown]
# # Khai phá Dữ liệu Tuyển sinh Đại học Việt Nam (Data Mining)
# ## Notebook 07: Khai phá Luật kết hợp (Association Rule Mining - Apriori)
#
# Notebook này thực hiện:
# 1. Discretize (rời rạc hóa) các trường dữ liệu liên tục thành các danh mục.
# 2. Biến đổi dữ liệu thành các giao dịch (Transactions).
# 3. Chạy thuật toán Apriori để tìm các tập phổ biến (Frequent Itemsets).
# 4. Trích xuất các luật kết hợp có ý nghĩa thống kê dựa trên Support, Confidence, và Lift.

# %%
import pandas as pd
import numpy as np
from src.mining.association_rules import AssociationRuleMiner

df = pd.read_csv("../data/processed/admission_processed.csv", encoding="utf-8-sig")

# %% [markdown]
# ### 1. Chuẩn bị dữ liệu và khởi tạo Miner

# %%
miner = AssociationRuleMiner(df)
df_transactions = miner.prepare_transaction_data()
print(f"Kích thước dữ liệu giao dịch: {df_transactions.shape}")
df_transactions.head()
# Out:
# Kích thước dữ liệu giao dịch: (187674, 1)
#                                                items
# 0  Ngành:Kỹ thuật - Công nghệ, TH:A00, Cạnh tranh...
# 1  Ngành:Kỹ thuật - Công nghệ, TH:A00, Cạnh tranh...
# 2  Ngành:Kỹ thuật - Công nghệ, TH:A00, Cạnh tranh...
# 3  Ngành:Kỹ thuật - Công nghệ, TH:A00, Cạnh tranh...
# 4  Ngành:Kỹ thuật - Công nghệ, TH:A00, Cạnh tranh...

# %% [markdown]
# ### 2. Khai phá luật kết hợp bằng Apriori

# %%
rules = miner.mine_rules(min_support=0.05, min_confidence=0.5)
print(f"Tìm thấy {len(rules)} luật kết hợp thỏa mãn điều kiện.")
# Out:
# 2026-06-29 17:12:30.304 | INFO     | src.mining.association_rules:mine_rules:97 - Association Rule Mining: support≥0.05, confidence≥0.5, lift≥1.2
# 2026-06-29 17:12:38.000 | INFO     | src.mining.association_rules:mine_rules:105 - Số transactions: 187,674
# 2026-06-29 17:12:38.180 | INFO     | src.mining.association_rules:mine_rules:111 - Số items unique: 147
# 2026-06-29 17:12:38.181 | INFO     | src.mining.association_rules:mine_rules:114 - Tìm frequent itemsets (Apriori)...
# 2026-06-29 17:12:38.217 | INFO     | src.mining.association_rules:mine_rules:130 - Số frequent itemsets: 34
# 2026-06-29 17:12:38.223 | SUCCESS  | src.mining.association_rules:mine_rules:152 - Tìm được 0 luật kết hợp có ý nghĩa
# Tìm thấy 0 luật kết hợp thỏa mãn điều kiện.

# %% [markdown]
# ### 3. Top 20 luật kết hợp có độ tin cậy cao nhất

# %%
miner.print_rules(rules, top_n=20)
# Out:
# Không có luật kết hợp nào để hiển thị.
